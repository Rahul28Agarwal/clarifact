# %% [markdown]
# #### NewAPI

# %%
from newsapi import NewsApiClient
import json
# Init
newsapi = NewsApiClient(api_key='ef5053c2ab08492fb2b4008fa2a04853')
sources = newsapi.get_sources()
print(sources)
# Out:
# {'status': 'ok', 'sources': [{'id': 'abc-news', 'name': 'ABC News', 'description': 'Your trusted source for breaking news, analysis, exclusive interviews, headlines, and videos at ABCNews.com.', 'url': 'https://abcnews.go.com', 'category': 'general', 'language': 'en', 'country': 'us'}, {'id': 'abc-news-au', 'name': 'ABC News (AU)', 'description': "Australia's most trusted source of local, national and world news. Comprehensive, independent, in-depth analysis, the latest business, sport, weather and more.", 'url': 'http://www.abc.net.au/news', 'category': 'general', 'language': 'en', 'country': 'au'}, {'id': 'aftenposten', 'name': 'Aftenposten', 'description': 'Norges ledende nettavis med alltid oppdaterte nyheter innenfor innenriks, utenriks, sport og kultur.', 'url': 'https://www.aftenposten.no', 'category': 'general', 'language': 'no', 'country': 'no'}, {'id': 'al-jazeera-english', 'name': 'Al Jazeera English', 'description': 'News, analysis from the Middle East and worldwide, mult
# ...

# %%
print('number of sources we can fetch at time = {}'.format(len(sources['sources'])))
# Out:
# number of sources we can fetch at time = 128

# %% [markdown]
# ### bing API

# %%
import http.client

conn = http.client.HTTPSConnection("bing-news-search1.p.rapidapi.com")

headers = {
    'x-bingapis-sdk': "true",
    'x-rapidapi-key': "02d028ab3dmsh600bbd560aa75bbp1a39e3jsn0ef3c700ff1b",
    'x-rapidapi-host': "bing-news-search1.p.rapidapi.com"
    }

conn.request("GET", "/news?textFormat=Raw&safeSearch=Off", headers=headers)

res = conn.getresponse()
data = res.read()

# %%
data
# Out:
# b'{"_type": "News", "webSearchUrl": "https:\\/\\/www.bing.com\\/news\\/search?q=top+stories&form=TNSA02", "value": [{"_type": "NewsArticle", "name": "Jack de Belin remains stood down by NRL after hung jury in sexual assault trial", "url": "https:\\/\\/www.msn.com\\/en-au\\/news\\/australia\\/jack-de-belin-remains-stood-down-by-nrl-after-hung-jury-in-sexual-assault-trial\\/ar-BB1gAqMX", "image": {"_type": "ImageObject", "thumbnail": {"_type": "ImageObject", "contentUrl": "https:\\/\\/www.bing.com\\/th?id=OVFT.vdFy669Mea-qgEcHaPTyaS&pid=News", "width": 1200, "height": 630}, "isLicensed": true}, "description": " Jack de Belin remains unable to play in the NRL after the league confirmed the St George Illawarra player is still subject to its no-fault stand-down policy as he waits to hear whether he will face", "provider": [{"_type": "Organization", "name": "The Guardian", "image": {"_type": "ImageObject", "thumbnail": {"_type": "ImageObject", "contentUrl": "https:\\/\\/www.bing.com\\/th?i
# ...

# %% [markdown]
# ### rapid api

# %%
import requests

url = "https://free-news.p.rapidapi.com/v1/search"

querystring = {"q":"bitcoin","lang":"en","page":"1","page_size":"25"}

headers = {
    'x-rapidapi-key': "<YOUR API KEY>",
    'x-rapidapi-host': "free-news.p.rapidapi.com"
    }

response = requests.request("GET", url, headers=headers, params=querystring)

print(response.text)
# Out:
# {"message":"You are not subscribed to this API."}

# %% [markdown]
# ### news catcher api

# %%
import requests

url = "https://newscatcher.p.rapidapi.com/v1/sources"

querystring = {"lang":"en"}

headers = {
    'x-rapidapi-key': "02d028ab3dmsh600bbd560aa75bbp1a39e3jsn0ef3c700ff1b",
    'x-rapidapi-host': "newscatcher.p.rapidapi.com"
    }

response = requests.request("GET", url, headers=headers, params=querystring)

print(response.text)
# Out:
# ["dailymail.co.uk","reddit.com","yahoo.com","thesun.co.uk","tellerreport.com","cbsnews.com","thestreet.com","michigansthumb.com","benzinga.com","americanbankingnews.com","thehour.com","mysanantonio.com","google.com","seekingalpha.com","nasdaq.com","apnews.com","usnews.com","businesswire.com","chron.com","reuters.com","independent.co.uk","marketwatch.com","openpr.com","gov.uk","express.co.uk","wallstreet-online.de","the-sun.com","e-servicis.com","indiatimes.com","allafrica.com","republicworld.com","forbes.com","thehindu.com","myplainview.com","washingtontimes.com","tncontentexchange.com","sec.gov","wiltonbulletin.com","globenewswire.com","thestar.com","manisteenews.com","thesun.ie","usatoday.com","indiaeveryday.com","gossipbucket.com","ncadvertiser.com","mirror.co.uk","screenrant.com","darientimes.com","theridgefieldpress.com","trumbulltimes.com","indianexpress.com","telegraph.co.uk","indiatoday.in","cnn.com","financialpost.com","prnewswire.com","breitbart.com","forextv.com","mayfield
# ...

# %%
import requests

url = "https://newscatcher.p.rapidapi.com/v1/search_free"

querystring = {"q":"*","lang":"en","media":"True"}

headers = {
    'x-rapidapi-key': "02d028ab3dmsh600bbd560aa75bbp1a39e3jsn0ef3c700ff1b",
    'x-rapidapi-host': "newscatcher.p.rapidapi.com"
    }

response = requests.request("GET", url, headers=headers, params=querystring)

# %%
len(response.text)
# Out:
# 57404

# %%
response.text
# Out:
# '{"status":"ok","total_hits":10000,"page":1,"total_pages":200,"page_size":50,"articles":[{"summary":"image copyrightGetty Imagesimage captionFuneral pyres have been built in parks and other empty spaces after Delhi\'s crematoriums reached capacityCrematoriums in the Indian capital Delhi have been forced to build makeshift funeral pyres, as the city runs out of space to cremate its dead.Staff are working around the clock, while parks and other empty spaces are also being utilised for cremations.Families have had to wait hours before being allowed to cremate their dead due to the rise in demand.Deaths have been surging in India as a second wave of infections devastates the country.","country":"US","author":null,"link":"https://www.bbc.com/news/world-asia-india-56897970","language":"en","media":"https://ichef.bbci.co.uk/news/1024/branded_news/11EBB/production/_118230437_gettyimages-1232552162.jpg","title":"India Covid: Delhi builds makeshift funeral pyres as deaths climb","media_content
# ...

# %%
import requests

url = "https://newscatcher.p.rapidapi.com/v1/search"

querystring = {"q":"Samantha Maiden","lang":"en","media":"True"}

headers = {
    'x-rapidapi-key': "02d028ab3dmsh600bbd560aa75bbp1a39e3jsn0ef3c700ff1b",
    'x-rapidapi-host': "newscatcher.p.rapidapi.com"
    }

response = requests.request("GET", url, headers=headers, params=querystring)

# %%
print(len(response.text))
for i in response.json()['articles']:
    print(i['author'])
# Out:
# 7281
# Republic World
# By Jay Neal sports@jacksonvilleprogress.com
# Ramya Palisetty MumbaiApril 28, 2021UPDATED: April 28, 2021 19:39 IST
# Robert Requintina
# Ramya Palisetty MumbaiApril 28, 2021UPDATED: April 28, 2021 13:35 IST

# %%
all_articles = newsapi.get_everything(from_param='2020-12-01',
                                      to='2020-12-12',
                                      language='en',)
# Out:
# ---------------------------------------------------------------------------
# NewsAPIException                          Traceback (most recent call last)
# <ipython-input-79-13dcb7a5ca98> in <module>
# ----> 1 all_articles = newsapi.get_everything(from_param='2020-12-01',
#       2                                       to='2020-12-12',
#       3                                       language='en',)
#
# ~\anaconda3\lib\site-packages\newsapi\newsapi_client.py in get_everything(self, q, qintitle, sources, domains, exclude_domains, from_param, to, language, sort_by, page, page_size)
#     324         # Check Status of Request
#     325         if r.status_code != requests.codes.ok:
# --> 326             raise NewsAPIException(r.json())
#     327
#     328         return r.json()
#
# ...

# %%
for i in all_articles['articles']:
    print(i['author'])
# Out:
# Elizabeth Yuko
# Beth Skwarecki on Vitals, shared by Beth Skwarecki to Lifehacker
# David Murphy
# Mike Winters on Two Cents, shared by Mike Winters to Lifehacker
# David Murphy
# David Murphy
# Emily Long
# Brendan Hesse
# Mike Winters on Two Cents, shared by Mike Winters to Lifehacker
# A.A. Newton
# Brendan Hesse
# A.A. Newton on Vitals, shared by A.A. Newton to Lifehacker
# David Murphy
# A.A. Newton
# Meghan Moravcik Walbert
# Mike Winters on Two Cents, shared by Mike Winters to Lifehacker
# Brendan Hesse
# Lindsey Ellefson
# Beth Skwarecki on Vitals, shared by Beth Skwarecki to Lifehacker
# Elizabeth Yuko

# %%
all_articles = newsapi.get_everything(q='Samantha Maiden',
                                      
                                      
                                      
                                      language='en',
                                      )

# %%
len(all_articles['articles'])
# Out:
# 14

# %%
for i in all_articles['articles']:
    print(i['author'])
# Out:
# Dmitry
# Cam Wilson
# Laura Tingle
# Stephen Mayne
# Tom Pyman
# Bhvishya Patel, Jo Tweedy, Tom Pyman
# Hayley Richardson
# MELANIE KEMBREY
# Amber Schultz
# Frontpagemagazine
# Elizabeth Daoud
# Ed Stockly
# Tom Pyman
# Ed Stockly

# %%
import http.client, urllib.parse

conn = http.client.HTTPConnection('api.mediastack.com')

params = urllib.parse.urlencode({
    'access_key': 'fc65f2307299dcba9f9de2ea08ce5546',
    'sort': 'published_desc',
    'limit': 100,
    })

conn.request('GET', '/v1/news?{}'.format(params))

res = conn.getresponse()
data = res.read()

# %%
df = json.loads(data.decode('utf-8'))

# %%
for i in df['data']:
    print(i['author'])
# Out:
# Oluwatomisin Amokeoja
# Vito Lamorte
# Andreas Knobloch
# Sue Min Liu
# Alessio Morra
# None
# Senne Croonen
# Davide Falcioni
# None
# Broede Carmody
# Broede Carmody
# Broede Carmody
# Broede Carmody
# Broede Carmody
# Broede Carmody
# Broede Carmody
# Broede Carmody
# Via AP news wire
# Martin Belam (now) and Helen Sullivan (earlier)
# None
# None
# By YONAH JEREMY BOB
# Alina Juravel
# David Martin
#
# David Martin
# None
# Pattaya Mail
# Jonathan Edwards
#
# None
# None
# ABMN Staff
# Inigo Roces
# ABMN Staff
# ABMN Staff
# ABMN Staff
# ABMN Staff
# ABMN Staff
# ABMN Staff
# ABMN Staff
# ABMN Staff
# ABMN Staff
# ABMN Staff
# ABMN Staff
# ABMN Staff
# ABMN Staff
# ABMN Staff
# ABMN Staff
# None
# None
# PA Media: Sport
# CM Guest Columnist
# repubblicawww@repubblica.it (Redazione Repubblica.it)
# None
# None
# None
# SALZBURG24 Redaktion
# AP News
# AP News
# AP News
# AP News
# None
# None
# None
# None
# None
# None
# None
# None
# None
# None
# None
# None
# None
# None
# ...

# %%
from serpwow.google_search_results import GoogleSearchResults
import json

# create the serpwow object, passing in our API key
serpwow = GoogleSearchResults("9B1ADC3384954C438385BA21681469F1")

# set up a dict for the search parameters
params = {
  "q" : "Stephanie Bedo",
  "search_type" : "news"
}

# retrieve the search results as JSON
result = serpwow.get_json(params)

# %%
result['search_information']
# Out:
# {'original_query_yields_zero_results': False,
#  'total_results': 6520,
#  'time_taken_displayed': 0.21,
#  'query_displayed': 'Stephanie Bedo'}

# %%
params = {
  "q" : "Rahul agarwal",
  "search_type" : "news"
}

# retrieve the search results as JSON
result = serpwow.get_json(params)

# %%
result['search_information']
# Out:
# {'original_query_yields_zero_results': False,
#  'total_results': 233000,
#  'time_taken_displayed': 0.21,
#  'query_displayed': 'Rahul agarwal'}

# %%
import requests

url = "https://bing-news-search1.p.rapidapi.com/news/trendingtopics"

querystring = {"safeSearch":"Off","textFormat":"Raw"}

headers = {
    'x-bingapis-sdk': "true",
    'x-rapidapi-key': "02d028ab3dmsh600bbd560aa75bbp1a39e3jsn0ef3c700ff1b",
    'x-rapidapi-host': "bing-news-search1.p.rapidapi.com"
    }

response = requests.request("GET", url, headers=headers, params=querystring)

# %%
print(response.json())
# Out:
# {'_type': 'TrendingTopics', 'value': [{'_type': 'News/Topic', 'webSearchUrl': 'https://www.bing.com/search?q=Iran+Issues+Warrant&form=TNSA01&filters=tnTID%3a%22E4CC248A-3D23-49cc-98E1-62452943EC69%22+tnVersion%3a%224033562%22+Segment%3a%22popularnow.carousel%22+tnCol%3a%220%22+tnScenario%3a%22TrendingTopicsAPI%22+tnOrder%3a%228fe7c18f-b4c2-4d33-b771-9df4ee790a4c%22', 'name': 'Iran issues warrant', 'image': {'_type': 'ImageObject', 'url': 'https://www.bing.com/th?id=OPN.RTNews_2_Kzsz5CPsmMWxh0iByjrg&c=14&rs=2&qlt=80&pcl=f9f9f9&pid=News', 'provider': [{'_type': 'Organization', 'name': 'AP'}]}, 'isBreakingNews': False, 'query': {'_type': 'Query', 'text': 'Iran Issues Warrant'}, 'newsSearchUrl': 'https://www.bing.com/news/search?q=Iran+Issues+Warrant&form=TNSA02&filters=tnTID%3a%22E4CC248A-3D23-49cc-98E1-62452943EC69%22+tnVersion%3a%224033562%22+Segment%3a%22popularnow.carousel%22+tnCol%3a%220%22+tnScenario%3a%22TrendingTopicsAPI%22+tnOrder%3a%228fe7c18f-b4c2-4d33-b771-9df4ee790a4c%22'},
# ...

# %%
import requests

url = "https://bing-news-search1.p.rapidapi.com/news"

querystring = {"textFormat":"Raw","safeSearch":"Off"}

headers = {
    'x-bingapis-sdk': "true",
    'x-rapidapi-key': "02d028ab3dmsh600bbd560aa75bbp1a39e3jsn0ef3c700ff1b",
    'x-rapidapi-host': "bing-news-search1.p.rapidapi.com"
    }

response = requests.request("GET", url, headers=headers, params=querystring)

# %%
import requests

url = "https://newscatcher.p.rapidapi.com/v1/search"

querystring = {"q":"Georgia Hitch","lang":"en","from":"2020/01/01"}

headers = {
    'x-rapidapi-key': "02d028ab3dmsh600bbd560aa75bbp1a39e3jsn0ef3c700ff1b",
    'x-rapidapi-host': "newscatcher.p.rapidapi.com"
    }

response = requests.request("GET", url, headers=headers, params=querystring)

# %%
articles = json.loads(response.text)['articles']

# %%
json.loads(response.text)
# Out:
# {'status': 'ok',
#  'total_hits': 10000,
#  'page': 20,
#  'total_pages': 2000,
#  'page_size': 5,
#  'articles': [{'summary': 'It looks like you will be able to order the Polestar 2 with a tow hitch and this could give it an edge over the Tesla Model 3.',
#    'country': 'NA',
#    'clean_url': 'insideevs.com',
#    'author': None,
#    'rights': 'insideevs.com',
#    'link': 'https://insideevs.com/news/438892/polestar-2-factory-tow-hitch-option/?utm_source=RSS&utm_medium=referral&utm_campaign=RSS-all-articles',
#    'rank': '10181',
#    'topic': 'NA',
#    'language': 'en',
#    'title': 'Polestar 2 Can Reportedly Be Ordered With A Factory Tow Hitch',
#    'published_date': '2020-08-13 12:03:37',
#    '_id': '8fb1f1290513474c8287e9eae3583316',
#    '_score': 14.108419},
# ...

# %%
len(articles)
# Out:
# 5

# %%
df = json.loads(data.decode('utf-8'))

# %%
all_articles = newsapi.get_everything(
                                      from_param='2021-04-04',
                                      to='2021-05-03',
                                      )
# Out:
# ---------------------------------------------------------------------------
# NewsAPIException                          Traceback (most recent call last)
# <ipython-input-185-e53ddd5bcfec> in <module>
# ----> 1 all_articles = newsapi.get_everything(
#       2                                       from_param='2021-04-04',
#       3                                       to='2021-05-03',
#       4                                       )
#
# ~\anaconda3\lib\site-packages\newsapi\newsapi_client.py in get_everything(self, q, qintitle, sources, domains, exclude_domains, from_param, to, language, sort_by, page, page_size)
#     324         # Check Status of Request
#     325         if r.status_code != requests.codes.ok:
# --> 326             raise NewsAPIException(r.json())
#     327
#     328         return r.json()
#
# ...

# %%
len(all_articles['articles'])
# Out:
# 20
